# %% [markdown]
# ### This notebook is based on PyTorch's custom datasets
# A custom dataset is a collection of data relating to a specific problem you're working on.

# %%
# Import the necessary libraries
import torch
from torch import nn
